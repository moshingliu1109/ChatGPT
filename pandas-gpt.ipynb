# %% [markdown]
# # Simple Query Question

# %%
# !pip install openai
# !pip install pandas-gpt

import openai
openai.api_key = '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'

import pandas_gpt

import pandas as pd

df = pd.read_csv('pii_and_all_states.csv')
df
# Out:
# ...
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone               1.0      700.00
# 1         141235    Lightning Charging Cable               1.0       14.95
# 2         141236            Wired Headphones               2.0       11.99
# 3         141237            27in FHD Monitor               1.0      149.99
# 4         141238            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable               1.0       14.95
# 185946    319667       AA Batteries (4-pack)               2.0        3.84
# 185947    319668             Vareebadd Phone               1.0      400.00
# 185948    319669            Wired Headphones               1.0       11.99
# 185949    319670  Bose SoundSport Headphones               1.0       99.99
#
# ...

# %%
df.ask('find all iPhone orders')
# Out:
#         Order ID Product  Quantity Ordered  Price Each      Order Date  \
# 0         141234  iPhone               1.0       700.0  01/22/19 21:25
# 104       141336  iPhone               1.0       700.0  01/09/19 18:23
# 164       141394  iPhone               1.0       700.0  01/06/19 16:54
# 207       141437  iPhone               1.0       700.0  01/10/19 15:40
# 228       141457  iPhone               1.0       700.0  01/09/19 22:11
# ...          ...     ...               ...         ...             ...
# 185873    319596  iPhone               1.0       700.0  12/01/19 08:44
# 185881    319603  iPhone               1.0       700.0  12/26/19 19:06
# 185907    319629  iPhone               1.0       700.0  12/18/19 15:41
# 185913    319634  iPhone               1.0       700.0  12/11/19 16:29
# 185944    319665  iPhone               1.0       700.0  12/15/19 11:13
#
#                                          Purchase Address  \
# ...

# %% [markdown]
# ## Complicated Query Question

# %%
df.ask('find all purchase from Laurenchester, NY in the current dataframe')
# Out:
#         Order ID           Product  Quantity Ordered  Price Each  \
# 3         141237  27in FHD Monitor               1.0      149.99
# 140484    276018      Google Phone               1.0      600.00
#
#             Order Date                                   Purchase Address  \
# 3       01/05/19 20:33          23081 Kyle Crest, Laurenchester, NY 10177
# 140484  10/24/19 01:46  78382 Noah Stream Suite 585, North Laurenchest...
#
#                 Credit Card          SSN
# 3       9431-1332-2561-3939  678-46-9684
# 140484  8086-9573-0018-6582  306-25-7380

# %%
df_with_state = df.ask('add a new state column which value is from address in the current dataframe')

# %%
df_with_state
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone               1.0      700.00
# 1         141235    Lightning Charging Cable               1.0       14.95
# 2         141236            Wired Headphones               2.0       11.99
# 3         141237            27in FHD Monitor               1.0      149.99
# 4         141238            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable               1.0       14.95
# 185946    319667       AA Batteries (4-pack)               2.0        3.84
# 185947    319668             Vareebadd Phone               1.0      400.00
# 185948    319669            Wired Headphones               1.0       11.99
# 185949    319670  Bose SoundSport Headphones               1.0       99.99
#
# ...

# %%
df_with_state_city = df_with_state.ask('add a new city column which value is from address in the current DataFrame')

# %%
df_with_state_city.ask('find purchase from city is Laurenchester in the current DataFrame')
# Out:
# Empty DataFrame
# Columns: [Order ID, Product, Quantity Ordered, Price Each, Order Date, Purchase Address, Credit Card, SSN, State, City]
# Index: []

# %%
df_with_state_city.ask('find purchase from city is Laurenchester ignore whitespace and city is from NY in the current DataFrame')
# Out:
#    Order ID           Product  Quantity Ordered  Price Each      Order Date  \
# 3    141237  27in FHD Monitor               1.0      149.99  01/05/19 20:33
#
#                             Purchase Address          Credit Card  \
# 3  23081 Kyle Crest, Laurenchester, NY 10177  9431-1332-2561-3939
#
#            SSN State           City
# 3  678-46-9684    NY  Laurenchester

# %% [markdown]
# # Business Concept

# %% [markdown]
# - PII: Personal Identification Information

# %%
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone               1.0      700.00
# 1         141235    Lightning Charging Cable               1.0       14.95
# 2         141236            Wired Headphones               2.0       11.99
# 3         141237            27in FHD Monitor               1.0      149.99
# 4         141238            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable               1.0       14.95
# 185946    319667       AA Batteries (4-pack)               2.0        3.84
# 185947    319668             Vareebadd Phone               1.0      400.00
# 185948    319669            Wired Headphones               1.0       11.99
# 185949    319670  Bose SoundSport Headphones               1.0       99.99
#
# ...

# %%
df_drop = df.ask('drop PII columns in the current dataframe')
# Out:
#    Order ID Product  Quantity Ordered  Price Each  Order Date  \
# 0         1       A               2.0        10.0  2021-01-01
# 1         2       B               1.0        20.0  2021-01-02
# 2         3       C               3.0        30.0  2021-01-03
#
#   Purchase Address       Credit Card          SSN
# 0       123 Street  1111222233334444  123-45-6789
# 1       456 Street  2222333344445555  234-56-7890
# 2       789 Street  3333444455556666  345-67-8901
#    Order ID Product  Quantity Ordered  Price Each  Order Date Purchase Address
# 0         1       A               2.0        10.0  2021-01-01       123 Street
# 1         2       B               1.0        20.0  2021-01-02       456 Street
# 2         3       C               3.0        30.0  2021-01-03       789 Street

# %%
df_drop
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone               1.0      700.00
# 1         141235    Lightning Charging Cable               1.0       14.95
# 2         141236            Wired Headphones               2.0       11.99
# 3         141237            27in FHD Monitor               1.0      149.99
# 4         141238            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable               1.0       14.95
# 185946    319667       AA Batteries (4-pack)               2.0        3.84
# 185947    319668             Vareebadd Phone               1.0      400.00
# 185948    319669            Wired Headphones               1.0       11.99
# 185949    319670  Bose SoundSport Headphones               1.0       99.99
#
# ...

# %% [markdown]
# # Business Enrichment

# %%
df.ask('add a new column "total price" which is quantity times price each in the current dataframe')
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone               1.0      700.00
# 1         141235    Lightning Charging Cable               1.0       14.95
# 2         141236            Wired Headphones               2.0       11.99
# 3         141237            27in FHD Monitor               1.0      149.99
# 4         141238            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable               1.0       14.95
# 185946    319667       AA Batteries (4-pack)               2.0        3.84
# 185947    319668             Vareebadd Phone               1.0      400.00
# 185948    319669            Wired Headphones               1.0       11.99
# 185949    319670  Bose SoundSport Headphones               1.0       99.99
#
# ...

# %% [markdown]
# # Aggregration Properties

# %%
df.ask('which day of the week has the largest number of orders')
# Out:
# 'Tuesday'

# %%
top10 = df.ask('what are the top 10 most popular products, and put them into a table')

# %% [markdown]
# ## Plotting

# %%
df = pd.read_csv('pii_and_all_states.csv')
df
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         141234                      iPhone               1.0      700.00
# 1         141235    Lightning Charging Cable               1.0       14.95
# 2         141236            Wired Headphones               2.0       11.99
# 3         141237            27in FHD Monitor               1.0      149.99
# 4         141238            Wired Headphones               1.0       11.99
# ...          ...                         ...               ...         ...
# 185945    319666    Lightning Charging Cable               1.0       14.95
# 185946    319667       AA Batteries (4-pack)               2.0        3.84
# 185947    319668             Vareebadd Phone               1.0      400.00
# 185948    319669            Wired Headphones               1.0       11.99
# 185949    319670  Bose SoundSport Headphones               1.0       99.99
#
# ...

# %%
import pandas as pd
import pandas_gpt

# %%
df.ask('plot monthly and hourly sales using line chart')

# %%
df.ask('plot monthly and hourly sales using bar chart')

# %%
df.ask('plot monthly and hourly sales using pie chart')

# %%
top10
# Out:
#                        Product  Quantity Ordered
# 5       AAA Batteries (4-pack)           31017.0
# 4        AA Batteries (4-pack)           27635.0
# 15        USB-C Charging Cable           23975.0
# 12    Lightning Charging Cable           23217.0
# 17            Wired Headphones           20557.0
# 6     Apple Airpods Headphones           15661.0
# 7   Bose SoundSport Headphones           13457.0
# 2             27in FHD Monitor            7550.0
# 18                      iPhone            6849.0
# 1       27in 4K Gaming Monitor            6244.0

# %%
top10.ask('horizontal bar plot of the current DataFrame')

# %%
df.ask('plot the correlation matrix')
